# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from pprint import pprint
from dataclasses import dataclass, field
from langchain.tools import tool, ToolRuntime
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.chat_models import init_chat_model
from langgraph.types import Command
from langchain.messages import HumanMessage, ToolMessage
from langchain.agents import AgentState
from langchain.agents.middleware import HumanInTheLoopMiddleware, dynamic_prompt, wrap_model_call, ModelRequest, ModelResponse
from typing import Callable

# %% [markdown]
# ## LLM Model

# %%
model = init_chat_model(model="gpt-5-nano")

# %% [markdown]
# ## Context

# %%
@dataclass
class LoginContext:
    users_db: dict = field(default_factory = lambda: {"user1@mail.com": "123",
                                                      "user2@mail.com": "321"})

# %% [markdown]
# ## State

# %%
class AuthState(AgentState):
    authenticated: bool

# %% [markdown]
# ## Tools

# %%
@tool
def check_inbox() -> str:
    """Check the inbox for recent emails"""
    return """
    Hi Julie,
    I'm going to be in town next week and was wondering if we could grab a coffee?
    - best, Jane (jane@example.com)
    """

@tool
def send_email(to: str, subject: str, body: str) -> str:
    """Send an response email"""
    return f"Email sent to {to} with subject {subject} and body {body}"

# %%
@tool
def authenticate(runtime: ToolRuntime, email: str, password: str):
    """Allow read inbox and send email tools only if user provides correct email and password"""
    if password_db := runtime.context.users_db.get(email):
        if password_db == password:
            return Command(update={
                "authenticated": True,
                "messages": [ToolMessage("Login Successful", tool_call_id=runtime.tool_call_id)]
            }
            )
    return Command(update={
        "authenticated": False,
        "messages": [ToolMessage("Login Failed", tool_call_id=runtime.tool_call_id)]
    }
    )

# %% [markdown]
# ## MiddleWare

# %% [markdown]
# ### Wrap Model Call - Dynamic Tool Call

# %%
@wrap_model_call
def dynamic_tool_call(request: ModelRequest, handler: Callable[[ModelRequest], ModelResponse]) -> ModelResponse:
    """Dynamically call tools based on the runtime context"""

    if  request.state.get("authenticated"):
        tools = [check_inbox, send_email]
    else:
        tools = [authenticate]
        request = request.override(tools=tools)
    return handler(request)

# %% [markdown]
# ### Wrap Model Call - Dynamic Prompt

# %%
authenticated_prompt = "You are a helpful assistant that can check the inbox and send emails."
unauthenticated_prompt = "You are a helpful assistant that can authenticate users."

@dynamic_prompt
def dynamic_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on authentication status"""
    authenticated = request.state.get("authenticated")

    if authenticated:
        return authenticated_prompt
    else:
        return unauthenticated_prompt

# %% [markdown]
# ### Human In The Loop

# %%
hitl_middleware = HumanInTheLoopMiddleware(interrupt_on={
                            "authenticate": False,
                            "check_inbox": False,
                            "send_email": True,
                        }
                    )

# %% [markdown]
# ## Email Agent

# %%
agent = create_agent(
    model=model,
    tools=[authenticate, check_inbox, send_email],
    state_schema=AuthState,
    context_schema=LoginContext,
    checkpointer=InMemorySaver(),
    middleware=[dynamic_tool_call, dynamic_prompt, hitl_middleware]
)

# %% [markdown]
# ## Testing Agent

# %% [markdown]
# First request

# %%
import threading

config = {"configurable": {"thread_id": threading.get_ident()}}

response = agent.invoke({
        "messages": [HumanMessage(content="Please check my inbox.")],
    },
    context=LoginContext(),
    config=config
)
pprint(response)
print("\n", '-'*100, "\n")
print(response['messages'][-1].content)
# Out:
# {'messages': [HumanMessage(content='Please check my inbox.', additional_kwargs={}, response_metadata={}, id='0948524d-1515-483b-aee2-b2c0bbad36d7'),
#               AIMessage(content='I can help with that. I need to sign you in first. Please provide:\n\n- Email address\n- Password\n\nI’ll sign you in and then show your latest messages (unread first by default). If you’d prefer, you can tell me to show only unread, or a specific folder/label.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 776, 'prompt_tokens': 151, 'total_tokens': 927, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ7BwEiONloPUABuUV1N0QUOXqhx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c704d-316d-7851-a642-4d06546bff03-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 776, 'total_tokens': 927, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})]}
#
#  ----------------------------------------------------------------------------------------------------
#
# I can help with that. I need to sign you in first. Please provide:
#
# - Email address
# - Password
#
# I’ll sign you in and then show your latest messages (unread first by default). If you’d prefer, you can tell me to show only unread, or a specific folder/label.

# %% [markdown]
# Login - sending wrong login

# %%
#sending a wrong login
response = agent.invoke({
        "messages": [HumanMessage(content="user3@mail.com : 123")],
    },
    context=LoginContext(),
    config=config
)

pprint(response)
print("\n", '-'*100, "\n")
print(response['messages'][-1].content)
# Out:
# {'authenticated': False,
#  'messages': [HumanMessage(content='Please check my inbox.', additional_kwargs={}, response_metadata={}, id='0948524d-1515-483b-aee2-b2c0bbad36d7'),
#               AIMessage(content='I can help with that. I need to sign you in first. Please provide:\n\n- Email address\n- Password\n\nI’ll sign you in and then show your latest messages (unread first by default). If you’d prefer, you can tell me to show only unread, or a specific folder/label.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 776, 'prompt_tokens': 151, 'total_tokens': 927, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ7BwEiONloPUABuUV1N0QUOXqhx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c704d-316d-7851-a642-4d06546bff03-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 776, 'total_tokens': 927, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}}),
#               HumanMessage(content='user3@mail.com : 123', additional_kwargs={}, response_metadata={}, id='9c18372c-b7d0-41e1-b3df-6ec4dc5fc840'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 221, 'prompt_tokens': 231, 'total_tokens': 452, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ9Bq3WEZoAoQq2Lz42SytVt3YOt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c704f-1324-71b2-a233-3f53700f8436-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'user3@mail.com', 'password': '123'}, 'id': 'call_8Rpg5RhhZG2j3p5u8c363MhP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 231, 'output_tokens': 221, 'total_tokens': 452, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#               ToolMessage(content='Login Failed', name='authenticate', id='7678eb19-229f-4ec4-8176-13807943083a', tool_call_id='call_8Rpg5RhhZG2j3p5u8c363MhP'),
#               AIMessage(content='Login failed for user3@mail.com.\n\nWhat would you like to do next?\n- Try again with the same credentials: re-enter your email and password.\n- Sign in with a different account: provide a different email and password.\n- Forgot password: say “reset password” and I’ll guide you through the recovery steps.\n\nOnce you’re signed in, I’ll fetch your latest messages (unread first by default).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 925, 'prompt_tokens': 266, 'total_tokens': 1191, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ9DM1lm5Nrq4bANdjHPQVgropyF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c704f-1f30-7521-9275-08061f7fb5dc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 266, 'output_tokens': 925, 'total_tokens': 1191, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}})]}
#
#  ----------------------------------------------------------------------------------------------------
#
# Login failed for user3@mail.com.
#
# What would you like to do next?
# - Try again with the same credentials: re-enter your email and password.
# - Sign in with a different account: provide a different email and password.
# - Forgot password: say “reset password” and I’ll guide you through the recovery steps.
#
# Once you’re signed in, I’ll fetch your latest messages (unread first by default).

# %% [markdown]
# Login - now sending a correct login

# %%
response = agent.invoke({
        "messages": [HumanMessage(content="user1@mail.com : 123")],
    },
    context=LoginContext(),
    config=config
)

pprint(response)
print("\n", '-'*100, "\n")
print(response['messages'][-1].content)
# Out:
# {'authenticated': True,
#  'messages': [HumanMessage(content='Please check my inbox.', additional_kwargs={}, response_metadata={}, id='0948524d-1515-483b-aee2-b2c0bbad36d7'),
#               AIMessage(content='I can help with that. I need to sign you in first. Please provide:\n\n- Email address\n- Password\n\nI’ll sign you in and then show your latest messages (unread first by default). If you’d prefer, you can tell me to show only unread, or a specific folder/label.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 776, 'prompt_tokens': 151, 'total_tokens': 927, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ7BwEiONloPUABuUV1N0QUOXqhx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c704d-316d-7851-a642-4d06546bff03-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 776, 'total_tokens': 927, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}}),
#               HumanMessage(content='user3@mail.com : 123', additional_kwargs={}, response_metadata={}, id='9c18372c-b7d0-41e1-b3df-6ec4dc5fc840'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 221, 'prompt_tokens': 231, 'total_tokens': 452, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ9Bq3WEZoAoQq2Lz42SytVt3YOt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c704f-1324-71b2-a233-3f53700f8436-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'user3@mail.com', 'password': '123'}, 'id': 'call_8Rpg5RhhZG2j3p5u8c363MhP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 231, 'output_tokens': 221, 'total_tokens': 452, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#               ToolMessage(content='Login Failed', name='authenticate', id='7678eb19-229f-4ec4-8176-13807943083a', tool_call_id='call_8Rpg5RhhZG2j3p5u8c363MhP'),
#               AIMessage(content='Login failed for user3@mail.com.\n\nWhat would you like to do next?\n- Try again with the same credentials: re-enter your email and password.\n- Sign in with a different account: provide a different email and password.\n- Forgot password: say “reset password” and I’ll guide you through the recovery steps.\n\nOnce you’re signed in, I’ll fetch your latest messages (unread first by default).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 925, 'prompt_tokens': 266, 'total_tokens': 1191, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ9DM1lm5Nrq4bANdjHPQVgropyF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c704f-1f30-7521-9275-08061f7fb5dc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 266, 'output_tokens': 925, 'total_tokens': 1191, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#               HumanMessage(content='user1@mail.com : 123', additional_kwargs={}, response_metadata={}, id='f7a3d94d-5782-4bf9-be01-40f9fb455ca9'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 367, 'total_tokens': 390, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZARvf9GFv4DXkTaTbUhI1MdOHRX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7050-47b7-74b3-8a4c-dce05793b032-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'user1@mail.com', 'password': '123'}, 'id': 'call_mznE5gKr2fbXoMBWQqx476Xt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 367, 'output_tokens': 23, 'total_tokens': 390, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Login Successful', name='authenticate', id='af48bea5-2bd4-4c14-bdb8-929e1b9723e4', tool_call_id='call_mznE5gKr2fbXoMBWQqx476Xt'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 449, 'total_tokens': 463, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZASLIw6tTmKMfhqBrISxFrNDHUx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7050-4af7-7af3-a7f6-a2a5baba716e-0', tool_calls=[{'name': 'check_inbox', 'args': {}, 'id': 'call_gZPtGs7QdfxlJ92cNfCQarSZ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 449, 'output_tokens': 14, 'total_tokens': 463, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="\n    Hi Julie,\n    I'm going to be in town next week and was wondering if we could grab a coffee?\n    - best, Jane (jane@example.com)\n    ", name='check_inbox', id='d7d646e8-ee4a-49e3-a946-5f9cd86898ad', tool_call_id='call_gZPtGs7QdfxlJ92cNfCQarSZ'),
#               AIMessage(content="Here are your latest messages (unread first):\n- Hi Julie,\n  I'm going to be in town next week and was wondering if we could grab a coffee?\n  - best, Jane (jane@example.com)\n\nWould you like me to reply to this message, or check for more unread emails?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 511, 'total_tokens': 575, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZATXUqRiPzZ1cZVYXobf2LTSYdY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7050-4eb0-7bc1-9769-0e65b0b5b8a4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 511, 'output_tokens': 64, 'total_tokens': 575, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
#
#  ----------------------------------------------------------------------------------------------------
#
# Here are your latest messages (unread first):
# - Hi Julie,
#   I'm going to be in town next week and was wondering if we could grab a coffee?
#   - best, Jane (jane@example.com)
#
# Would you like me to reply to this message, or check for more unread emails?

# %% [markdown]
# Requesting to reply to the email

# %%
response = agent.invoke({
        "messages": [HumanMessage(content="Yes, reply to this message")],
    },
    context=LoginContext(),
    config=config
)

pprint(response)
print("\n", '-'*100, "\n")
print(response['messages'][-1].content)
# Out:
# {'__interrupt__': [Interrupt(value={'action_requests': [{'args': {'body': 'Hi '
#                                                                           'Jane,\n'
#                                                                           '\n'
#                                                                           'That '
#                                                                           'sounds '
#                                                                           'great! '
#                                                                           'I’d '
#                                                                           'love '
#                                                                           'to '
#                                                                           'grab '
#                                                                           'coffee '
#                                                                           'next '
#                                                                           'week. '
#                                                                           'What '
#                                                                           'day '
#                                                                           'and '
#                                                                           'time '
#                                                                           'work '
#                                                                           'best '
#                                                                           'for '
#                                                                           'you?\n'
#                                                                           '\n'
#                                                                           'Looking '
#                                                                           'forward '
#                                                                           'to '
#                                                                           'it,\n'
#                                                                           'Julie',
#                                                                   'subject': 'Re: '
#                                                                              'Coffee '
#                                                                              'next '
#                                                                              'week',
#                                                                   'to': 'jane@example.com'},
#                                                          'description': 'Tool '
#                                                                         'execution '
#                                                                         'requires '
#                                                                         'approval\n'
#                                                                         '\n'
#                                                                         'Tool: '
#                                                                         'send_email\n'
#                                                                         'Args: '
#                                                                         "{'to': "
#                                                                         "'jane@example.com', "
#                                                                         "'subject': "
#                                                                         "'Re: "
#                                                                         'Coffee '
#                                                                         'next '
#                                                                         "week', "
#                                                                         "'body': "
#                                                                         "'Hi "
#                                                                         'Jane,\\n\\nThat '
#                                                                         'sounds '
#                                                                         'great! '
#                                                                         'I’d '
#                                                                         'love '
#                                                                         'to '
#                                                                         'grab '
#                                                                         'coffee '
#                                                                         'next '
#                                                                         'week. '
#                                                                         'What '
#                                                                         'day '
#                                                                         'and '
#                                                                         'time '
#                                                                         'work '
#                                                                         'best '
#                                                                         'for '
#                                                                         'you?\\n\\nLooking '
#                                                                         'forward '
#                                                                         'to '
#                                                                         "it,\\nJulie'}",
#                                                          'name': 'send_email'}],
#                                     'review_configs': [{'action_name': 'send_email',
#                                                         'allowed_decisions': ['approve',
#                                                                               'edit',
#                                                                               'reject']}]},
#                              id='2b3ff343db89ac1a0c34b4d1c8edf11d')],
#  'authenticated': True,
#  'messages': [HumanMessage(content='Please check my inbox.', additional_kwargs={}, response_metadata={}, id='0948524d-1515-483b-aee2-b2c0bbad36d7'),
#               AIMessage(content='I can help with that. I need to sign you in first. Please provide:\n\n- Email address\n- Password\n\nI’ll sign you in and then show your latest messages (unread first by default). If you’d prefer, you can tell me to show only unread, or a specific folder/label.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 776, 'prompt_tokens': 151, 'total_tokens': 927, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ7BwEiONloPUABuUV1N0QUOXqhx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c704d-316d-7851-a642-4d06546bff03-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 776, 'total_tokens': 927, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}}),
#               HumanMessage(content='user3@mail.com : 123', additional_kwargs={}, response_metadata={}, id='9c18372c-b7d0-41e1-b3df-6ec4dc5fc840'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 221, 'prompt_tokens': 231, 'total_tokens': 452, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ9Bq3WEZoAoQq2Lz42SytVt3YOt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c704f-1324-71b2-a233-3f53700f8436-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'user3@mail.com', 'password': '123'}, 'id': 'call_8Rpg5RhhZG2j3p5u8c363MhP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 231, 'output_tokens': 221, 'total_tokens': 452, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#               ToolMessage(content='Login Failed', name='authenticate', id='7678eb19-229f-4ec4-8176-13807943083a', tool_call_id='call_8Rpg5RhhZG2j3p5u8c363MhP'),
#               AIMessage(content='Login failed for user3@mail.com.\n\nWhat would you like to do next?\n- Try again with the same credentials: re-enter your email and password.\n- Sign in with a different account: provide a different email and password.\n- Forgot password: say “reset password” and I’ll guide you through the recovery steps.\n\nOnce you’re signed in, I’ll fetch your latest messages (unread first by default).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 925, 'prompt_tokens': 266, 'total_tokens': 1191, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ9DM1lm5Nrq4bANdjHPQVgropyF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c704f-1f30-7521-9275-08061f7fb5dc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 266, 'output_tokens': 925, 'total_tokens': 1191, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#               HumanMessage(content='user1@mail.com : 123', additional_kwargs={}, response_metadata={}, id='f7a3d94d-5782-4bf9-be01-40f9fb455ca9'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 367, 'total_tokens': 390, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZARvf9GFv4DXkTaTbUhI1MdOHRX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7050-47b7-74b3-8a4c-dce05793b032-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'user1@mail.com', 'password': '123'}, 'id': 'call_mznE5gKr2fbXoMBWQqx476Xt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 367, 'output_tokens': 23, 'total_tokens': 390, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Login Successful', name='authenticate', id='af48bea5-2bd4-4c14-bdb8-929e1b9723e4', tool_call_id='call_mznE5gKr2fbXoMBWQqx476Xt'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 449, 'total_tokens': 463, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZASLIw6tTmKMfhqBrISxFrNDHUx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7050-4af7-7af3-a7f6-a2a5baba716e-0', tool_calls=[{'name': 'check_inbox', 'args': {}, 'id': 'call_gZPtGs7QdfxlJ92cNfCQarSZ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 449, 'output_tokens': 14, 'total_tokens': 463, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="\n    Hi Julie,\n    I'm going to be in town next week and was wondering if we could grab a coffee?\n    - best, Jane (jane@example.com)\n    ", name='check_inbox', id='d7d646e8-ee4a-49e3-a946-5f9cd86898ad', tool_call_id='call_gZPtGs7QdfxlJ92cNfCQarSZ'),
#               AIMessage(content="Here are your latest messages (unread first):\n- Hi Julie,\n  I'm going to be in town next week and was wondering if we could grab a coffee?\n  - best, Jane (jane@example.com)\n\nWould you like me to reply to this message, or check for more unread emails?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 511, 'total_tokens': 575, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZATXUqRiPzZ1cZVYXobf2LTSYdY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7050-4eb0-7bc1-9769-0e65b0b5b8a4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 511, 'output_tokens': 64, 'total_tokens': 575, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               HumanMessage(content='Yes, reply to this message', additional_kwargs={}, response_metadata={}, id='0c742451-ca76-48ad-ba48-369656e41328'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 841, 'prompt_tokens': 588, 'total_tokens': 1429, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZDIK2SakkacS7Uq1IX73xzn1EcM', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7052-f4a5-72f0-9a2c-591a9d2a3f62-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'jane@example.com', 'subject': 'Re: Coffee next week', 'body': 'Hi Jane,\n\nThat sounds great! I’d love to grab coffee next week. What day and time work best for you?\n\nLooking forward to it,\nJulie'}, 'id': 'call_pWHryghys6cnAG6rxwmtLOTD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 588, 'output_tokens': 841, 'total_tokens': 1429, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}
#
#  ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Human in the loop interrupt to approve/reject/edit email reply

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# Hi Jane,
#
# That sounds great! I’d love to grab coffee next week. What day and time work best for you?
#
# Looking forward to it,
# Julie

# %% [markdown]
# Approving the reply

# %%
response = agent.invoke(
    Command(
        resume={"decisions": [{"type": "approve"}]}  # or "reject"
    ),
    config=config
)

pprint(response)
print("\n", '-'*100, "\n")
print(response['messages'][-1].content)
# Out:
# {'authenticated': True,
#  'messages': [HumanMessage(content='Please check my inbox.', additional_kwargs={}, response_metadata={}, id='0948524d-1515-483b-aee2-b2c0bbad36d7'),
#               AIMessage(content='I can help with that. I need to sign you in first. Please provide:\n\n- Email address\n- Password\n\nI’ll sign you in and then show your latest messages (unread first by default). If you’d prefer, you can tell me to show only unread, or a specific folder/label.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 776, 'prompt_tokens': 151, 'total_tokens': 927, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ7BwEiONloPUABuUV1N0QUOXqhx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c704d-316d-7851-a642-4d06546bff03-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 776, 'total_tokens': 927, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}}),
#               HumanMessage(content='user3@mail.com : 123', additional_kwargs={}, response_metadata={}, id='9c18372c-b7d0-41e1-b3df-6ec4dc5fc840'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 221, 'prompt_tokens': 231, 'total_tokens': 452, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ9Bq3WEZoAoQq2Lz42SytVt3YOt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c704f-1324-71b2-a233-3f53700f8436-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'user3@mail.com', 'password': '123'}, 'id': 'call_8Rpg5RhhZG2j3p5u8c363MhP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 231, 'output_tokens': 221, 'total_tokens': 452, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}}),
#               ToolMessage(content='Login Failed', name='authenticate', id='7678eb19-229f-4ec4-8176-13807943083a', tool_call_id='call_8Rpg5RhhZG2j3p5u8c363MhP'),
#               AIMessage(content='Login failed for user3@mail.com.\n\nWhat would you like to do next?\n- Try again with the same credentials: re-enter your email and password.\n- Sign in with a different account: provide a different email and password.\n- Forgot password: say “reset password” and I’ll guide you through the recovery steps.\n\nOnce you’re signed in, I’ll fetch your latest messages (unread first by default).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 925, 'prompt_tokens': 266, 'total_tokens': 1191, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZ9DM1lm5Nrq4bANdjHPQVgropyF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c704f-1f30-7521-9275-08061f7fb5dc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 266, 'output_tokens': 925, 'total_tokens': 1191, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}}),
#               HumanMessage(content='user1@mail.com : 123', additional_kwargs={}, response_metadata={}, id='f7a3d94d-5782-4bf9-be01-40f9fb455ca9'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 367, 'total_tokens': 390, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZARvf9GFv4DXkTaTbUhI1MdOHRX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7050-47b7-74b3-8a4c-dce05793b032-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'user1@mail.com', 'password': '123'}, 'id': 'call_mznE5gKr2fbXoMBWQqx476Xt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 367, 'output_tokens': 23, 'total_tokens': 390, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Login Successful', name='authenticate', id='af48bea5-2bd4-4c14-bdb8-929e1b9723e4', tool_call_id='call_mznE5gKr2fbXoMBWQqx476Xt'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 449, 'total_tokens': 463, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZASLIw6tTmKMfhqBrISxFrNDHUx', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7050-4af7-7af3-a7f6-a2a5baba716e-0', tool_calls=[{'name': 'check_inbox', 'args': {}, 'id': 'call_gZPtGs7QdfxlJ92cNfCQarSZ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 449, 'output_tokens': 14, 'total_tokens': 463, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="\n    Hi Julie,\n    I'm going to be in town next week and was wondering if we could grab a coffee?\n    - best, Jane (jane@example.com)\n    ", name='check_inbox', id='d7d646e8-ee4a-49e3-a946-5f9cd86898ad', tool_call_id='call_gZPtGs7QdfxlJ92cNfCQarSZ'),
#               AIMessage(content="Here are your latest messages (unread first):\n- Hi Julie,\n  I'm going to be in town next week and was wondering if we could grab a coffee?\n  - best, Jane (jane@example.com)\n\nWould you like me to reply to this message, or check for more unread emails?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 511, 'total_tokens': 575, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZATXUqRiPzZ1cZVYXobf2LTSYdY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7050-4eb0-7bc1-9769-0e65b0b5b8a4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 511, 'output_tokens': 64, 'total_tokens': 575, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               HumanMessage(content='Yes, reply to this message', additional_kwargs={}, response_metadata={}, id='0c742451-ca76-48ad-ba48-369656e41328'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 841, 'prompt_tokens': 588, 'total_tokens': 1429, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZDIK2SakkacS7Uq1IX73xzn1EcM', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c7052-f4a5-72f0-9a2c-591a9d2a3f62-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'jane@example.com', 'subject': 'Re: Coffee next week', 'body': 'Hi Jane,\n\nThat sounds great! I’d love to grab coffee next week. What day and time work best for you?\n\nLooking forward to it,\nJulie'}, 'id': 'call_pWHryghys6cnAG6rxwmtLOTD', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 588, 'output_tokens': 841, 'total_tokens': 1429, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}),
#               ToolMessage(content='Email sent to jane@example.com with subject Re: Coffee next week and body Hi Jane,\n\nThat sounds great! I’d love to grab coffee next week. What day and time work best for you?\n\nLooking forward to it,\nJulie', name='send_email', id='fd854f6e-51c5-47e5-bedb-0b73c73d4f29', tool_call_id='call_pWHryghys6cnAG6rxwmtLOTD'),
#               AIMessage(content="Email sent to jane@example.com with subject Re: Coffee next week and body Hi Jane,\n\nThat sounds great! I’d love to grab coffee next week. What day and time work best for you?\n\nLooking forward to it,\nJulie\n\nYou're all set! If you'd like, I can check for more unread emails or respond to another message.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 71, 'prompt_tokens': 712, 'total_tokens': 783, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DAZJclJ8V7omCVWKUyLbl2SOK1FOV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c7058-f4e8-79c2-bb57-2bdef5b063f7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 712, 'output_tokens': 71, 'total_tokens': 783, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
#
#  ----------------------------------------------------------------------------------------------------
#
# Email sent to jane@example.com with subject Re: Coffee next week and body Hi Jane,
#
# That sounds great! I’d love to grab coffee next week. What day and time work best for you?
#
# Looking forward to it,
# Julie
#
# You're all set! If you'd like, I can check for more unread emails or respond to another message.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
